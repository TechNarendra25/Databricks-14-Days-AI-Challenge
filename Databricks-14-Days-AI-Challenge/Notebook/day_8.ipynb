# %% [markdown]
# Unity Catalog Governance

# %%
# %sql
CREATE TABLE IF NOT EXISTS workspace.ecommerce.silver_events
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS workspace.ecommerce.gold_product_performance
USING DELTA;

# %%
# %sql
SHOW TABLES IN workspace.ecommerce;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>ecommerce</td><td>bronze_events</td><td>false</td></tr><tr><td>ecommerce</td><td>events_delta</td><td>false</td></tr><tr><td>ecommerce</td><td>gold_product_performance</td><td>false</td></tr><tr><td>ecommerce</td><td>silver_events</td><td>false</td></tr></tbody></table></div>
